# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Dropping Columns in a DF

# %%
df = pd.read_csv('/Users/mike/Github/python-data-cleaning/Datasets/BL-Flickr-Images-Book.csv')
df.head()
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
# 可以看到feature值的空白与否
# 删除值
to_drop = ['Edition Statement',
                'Corporate Author',
                'Corporate Contributors',
                'Former owner',
                'Engraver',
                'Contributors',
                'Issuance type',
                'Shelfmarks']
df.drop(to_drop, inplace = True, axis= 1)

# %% [markdown]
# ## [drop函数详解](https://blog.csdn.net/nuaadot/article/details/78304642)

# %% [markdown]
# ### 清理无效数据

# %%
df[df.isnull()]  #返回的是个true或false的Series对象（掩码对象），进而筛选出我们需要的特定数据。
df[df.notnull()]

df.dropna()     #将所有含有nan项的row删除
df.dropna(axis=1,thresh=3)  #将在列的方向上三个为NaN的项删除
df.dropna(how='all')        #将全部项都是nan的row删除
# Out:
#       Identifier                               Place of Publication  \
# 0            206                                             London
# 1            216                           London; Virtue & Yorston
# 2            218                                             London
# 3            472                                             London
# 4            480                                             London
# 5            481                                             London
# 6            519                                             London
# 7            667                pp. 40. G. Bryan & Co: Oxford, 1898
# 8            874                                            London]
# 9           1143                                             London
# 10          1280                                           Coventry
# 11          1808                                        Christiania
# 12          1905                                            Firenze
# ...

# %% [markdown]
# ### 填充无效值

# %%
df.fillna(0)
df.fillna({1:0, 2:0.5})         #对第一列nan值赋0，第二列赋值0.5
df.fillna(method='ffill')   #在列方向上以前一个值作为值赋给NaN
# Out:
#       Identifier                               Place of Publication  \
# 0            206                                             London
# 1            216                           London; Virtue & Yorston
# 2            218                                             London
# 3            472                                             London
# 4            480                                             London
# 5            481                                             London
# 6            519                                             London
# 7            667                pp. 40. G. Bryan & Co: Oxford, 1898
# 8            874                                            London]
# 9           1143                                             London
# 10          1280                                           Coventry
# 11          1808                                        Christiania
# 12          1905                                            Firenze
# ...

# %% [markdown]
# ### drop函数的使用

# %% [markdown]
# #### （1）drop函数的使用：删除行、删除列

# %%
print frame.drop(['a']) # 默认删除行
print frame.drop(['Ohio'], axis = 1) # 1列0行 axis
# Out:
#   File "<ipython-input-8-d6f7530d65d8>", line 1
#     print frame.drop(['a']) # 默认删除行
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### （2）drop函数的使用：inplace参数

# %%
DF= DF.drop('column_name', axis=1)；
DF.drop('column_name',axis=1, inplace=True)
DF.drop([DF.columns[[0,1, 3]]], axis=1, inplace=True)   # Note: zero indexed

# %% [markdown]
# 注意：凡是会对原数组作出修改并返回一个新数组的，往往都有一个 inplace可选参数。如果手动设定为True（默认为False），那么原数组直接就被替换。也就是说，采用inplace=True之后，原数组名（如2和3情况所示）对应的内存值直接改变；

# %% [markdown]
# #### （3）drop函数的使用：数据类型转换

# %%
df['Name'] = df['Name'].astype(np.da tetime64)

# %% [markdown]
# DataFrame.astype() 方法可对整个DataFrame或某一列进行数据格式转换，支持Python和NumPy的数据类型。

# %% [markdown]
# # Changing the Index of a DataFrame

# %%
df['Identifier'].is_unique
# Out:
# True

# %%
df = df.set_index('Identifier')
df.head()
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London         1879 [1878]
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# ...

# %%
df.loc[206]
# Out:
# Place of Publication                                               London
# Date of Publication                                           1879 [1878]
# Publisher                                                S. Tinsley & Co.
# Title                                   Walter Forbes. [A novel.] By A. A
# Author                                                              A. A.
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Name: 206, dtype: object

# %% [markdown]
# ## Tidying up Field in the Data

# %%
df.get_dtype_counts()
# Out:
# object    6
# dtype: int64

# %%
df.loc[1905:, 'Date of Publication'].head(10)
# Out:
# Identifier
# 1905           1888
# 1929    1839, 38-54
# 2836           1897
# 2854           1865
# 2956        1860-63
# 2957           1873
# 3017           1866
# 3131           1899
# 4598           1814
# 4884           1820
# Name: Date of Publication, dtype: object

# %%
extr = df['Date of Publication'].str.extract(r'^(\d{4})', expand=False)
# 正则表达式
#\d表示任意数字，{4}重复这个规则四次。^字符匹配字符串的开头，括号表示一个捕获组，
# 该捕获组向熊猫发出信号，表示我们要提取正则表达式的这一部分。我们想避免[以字符串开头]的情况。
# 用正则表达式表达数据集
extr.head()
# Out:
# Identifier
# 206    1879
# 216    1868
# 218    1869
# 472    1851
# 480    1857
# Name: Date of Publication, dtype: object

# %%
df['Date of Publication'] = pd.to_numeric(extr)
df['Date of Publication'].dtype
# to_numeric 转为数值 不能处理 Serice
# Out:
# dtype('float64')

# %%
df['Date of Publication'].isnull().sum()/len(df)
#这导致每10个值中就有1个丢失，这对于现在能够对剩余的有效值进行计算来说是一个很小的代价:
# Out:
# 0.11717147339205986

# %% [markdown]
# ## Combining str Methods with NumPy to Clean Columns

# %% [markdown]
# To clean the Place of Publication field, we can combine Pandas str methods with NumPy’s np.where function, which is basically a vectorized form of Excel’s IF() macro. It has the following syntax:

# %%
np.where(, then, else)
# Out:
#   File "<ipython-input-17-317ffd659858>", line 1
#     np.where(, then, else)
#              ^
# SyntaxError: invalid syntax

# %%
np.where(condition1, x1,
        np.where(condition2, x2),
            np.where(condition3, x3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-597ca83f2281> in <module>
# ----> 1 np.where(condition1, x1,
#       2         np.where(condition2, x2),
#       3             np.where(condition3, x3))
#
# NameError: name 'condition1' is not defined

# %%
df['Place of Publication'].head(10)
# Out:
# Identifier
# 206                                  London
# 216                London; Virtue & Yorston
# 218                                  London
# 472                                  London
# 480                                  London
# 481                                  London
# 519                                  London
# 667     pp. 40. G. Bryan & Co: Oxford, 1898
# 874                                 London]
# 1143                                 London
# Name: Place of Publication, dtype: object

# %% [markdown]
# two specific ectries

# %%
df.loc[4157862]
# Out:
# Place of Publication                                  Newcastle-upon-Tyne
# Date of Publication                                                  1867
# Publisher                                                      T. Fordyce
# Title                   Local Records; or, Historical Register of rema...
# Author                      FORDYCE, T. - Printer, of Newcastle-upon-Tyne
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Name: 4157862, dtype: object

# %%
df.loc[4159587]
# Out:
# Place of Publication                                  Newcastle upon Tyne
# Date of Publication                                                  1834
# Publisher                                                Mackenzie & Dent
# Title                   An historical, topographical and descriptive v...
# Author                                              Mackenzie, E. (Eneas)
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Name: 4159587, dtype: object

# %% [markdown]
# These two books were published in the same place, but one has hyphens in the name of the place while the other does not.
#
# To clean this column in one sweep, we can use str.contains() to get a boolean mask.
#
# We clean the column as follows:

# %%
pub = df['Place of Publication']
london = pub.str.contains('London') # get a boolean mask
london[:5]
# Out:
# Identifier
# 206    True
# 216    True
# 218    True
# 472    True
# 480    True
# Name: Place of Publication, dtype: bool

# %%
oxford = pub.str.contains('Oxford')

# %%
df['Place of Publication'] = np.where(london, 'London',
                                      np.where(oxford, 'Oxford',
                                               pub.str.replace('-', ' ')))
df['Place of Publication'].head()
# Out:
# Identifier
# 206    London
# 216    London
# 218    London
# 472    London
# 480    London
# Name: Place of Publication, dtype: object

# %% [markdown]
# 在这里np function 在嵌套结构中调用，条件为使用str.contains()
# 获得的一系列布尔值。contains()方法的工作原理类似于内置in关键字，
# 该关键字用于在可迭代的(或字符串中的子字符串)中查找实体的出现。
#
# 要使用的替换是一个表示我们希望发布位置的字符串。
# 我们还用一个带有str.replace()的空格替换连字符，并重新分配到dataframe中的列。

# %%
df.head()
# Out:
#            Place of Publication  Date of Publication              Publisher  \
# Identifier
# 206                      London               1879.0       S. Tinsley & Co.
# 216                      London               1868.0           Virtue & Co.
# 218                      London               1869.0  Bradbury, Evans & Co.
# 472                      London               1851.0          James Darling
# 480                      London               1857.0   Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# 480         [The World in which I live, and my place in it...  A., E. S.
#
# ...

# %% [markdown]
# ## Cleaning the Entire Dataset Using the applymap Function

# %%
university_towns = []
with open('/Users/mike/Github/python-data-cleaning/Datasets/university_towns.txt') as file:
    for line in file:
        if '[edit]' in line:
            # Remember this 'state' until the next is found
            state = line
        else:
            # Otherwise, we hava a city: keep 'state' as last-seen
            university_towns.append((state, line))
university_towns[:5]
# Out:
# [('Alabama[edit]\n', 'Auburn (Auburn University)[1]\n'),
#  ('Alabama[edit]\n', 'Florence (University of North Alabama)\n'),
#  ('Alabama[edit]\n', 'Jacksonville (Jacksonville State University)[2]\n'),
#  ('Alabama[edit]\n', 'Livingston (University of West Alabama)[2]\n'),
#  ('Alabama[edit]\n', 'Montevallo (University of Montevallo)[2]\n')]

# %%
towns_df = pd.DataFrame(university_towns,
                       columns = ['State', 'RegionName'])
towns_df.head()
# Out:
#              State                                         RegionName
# 0  Alabama[edit]\n                    Auburn (Auburn University)[1]\n
# 1  Alabama[edit]\n           Florence (University of North Alabama)\n
# 2  Alabama[edit]\n  Jacksonville (Jacksonville State University)[2]\n
# 3  Alabama[edit]\n       Livingston (University of West Alabama)[2]\n
# 4  Alabama[edit]\n         Montevallo (University of Montevallo)[2]\n

# %%
def get_citystate(item):
    if '(' in item:
        return item[:item.find('(')]
    elif '[' in item:
        return item[:item.find('[')]
    else:
        return item

# %%
towns_df = towns_df.applymap(get_citystate)
towns_df.head()
# Out:
#      State     RegionName
# 0  Alabama        Auburn
# 1  Alabama      Florence
# 2  Alabama  Jacksonville
# 3  Alabama    Livingston
# 4  Alabama    Montevallo

# %% [markdown]
# ## Renaming Columns and Skipping Rows

# %%
olympics_df = pd.read_csv('/Users/mike/Github/python-data-cleaning/Datasets/olympics.csv', header = 1)
olympics_df.head()
# Out:
#                 Unnamed: 0  ? Summer  01 !  02 !  03 !  Total  ? Winter  \
# 0        Afghanistan (AFG)        13     0     0     2      2         0
# 1            Algeria (ALG)        12     5     2     8     15         3
# 2          Argentina (ARG)        23    18    24    28     70        18
# 3            Armenia (ARM)         5     1     2     9     12         6
# 4  Australasia (ANZ) [ANZ]         2     3     4     5     12         0
#
#    01 !.1  02 !.1  03 !.1  Total.1  ? Games  01 !.2  02 !.2  03 !.2  \
# 0       0       0       0        0       13       0       0       2
# 1       0       0       0        0       15       5       2       8
# 2       0       0       0        0       41      18      24      28
# 3       0       0       0        0       11       1       2       9
# 4       0       0       0        0        2       3       4       5
#
#    Combined total
# 0               2
# 1              15
# 2              70
# 3              12
# 4              12

# %%
new_names = olympics_df.columns.values

# %%
new_names =  {'Unnamed: 0': 'Country',
               '? Summer': 'Summer Olympics',
               '01 !': 'Gold',
               '02 !': 'Silver',
               '03 !': 'Bronze',
               '? Winter': 'Winter Olympics',
               '01 !.1': 'Gold.1',
               '02 !.1': 'Silver.1',
               '03 !.1': 'Bronze.1',
               '? Games': '# Games',
               '01 !.2': 'Gold.2',
               '02 !.2': 'Silver.2',
               '03 !.2': 'Bronze.2'}

# %%
olympics_df.rename(columns=new_names, inplace=True)
# 重新命名

# %%
olympics_df.head()
# Out:
#                    Country  Summer Olympics  Gold  Silver  Bronze  Total  \
# 0        Afghanistan (AFG)               13     0       0       2      2
# 1            Algeria (ALG)               12     5       2       8     15
# 2          Argentina (ARG)               23    18      24      28     70
# 3            Armenia (ARM)                5     1       2       9     12
# 4  Australasia (ANZ) [ANZ]                2     3       4       5     12
#
#    Winter Olympics  Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# 0                0       0         0         0        0       13       0
# 1                3       0         0         0        0       15       5
# 2               18       0         0         0        0       41      18
# 3                6       0         0         0        0       11       1
# 4                0       0         0         0        0        2       3
#
#    Silver.2  Bronze.2  Combined total
# 0         0         2               2
# ...

# %% [markdown]
# ## Python Data Cleaning: Recap and Resources
